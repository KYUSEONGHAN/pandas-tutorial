# %% [markdown]
# <a href="https://colab.research.google.com/github/KYUSEONGHAN/pandas-tutorial/blob/master/ch2_dataframe_%EC%83%9D%EC%84%B1%EA%B3%BC_%EC%A0%80%EC%9E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
city = ['서울', '부산', '인천', '대구', '대전', '광주', '수원', '울산', '고양', '용인']
population = [9741381, 3416918, 2925967, 2453041, 1525849, 1496172, 1193894, 1147037, 1068641, 1061440]

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['도시', '인구수'], index=range(10))
df
# Out:
#     도시  인구수
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN
# 5  NaN  NaN
# 6  NaN  NaN
# 7  NaN  NaN
# 8  NaN  NaN
# 9  NaN  NaN

# %%
df['도시'] = city
df['인구수'] = population
df
# Out:
#    도시      인구수
# 0  서울  9741381
# 1  부산  3416918
# 2  인천  2925967
# 3  대구  2453041
# 4  대전  1525849
# 5  광주  1496172
# 6  수원  1193894
# 7  울산  1147037
# 8  고양  1068641
# 9  용인  1061440

# %%
df_dict = {'도시': city, '인구수': population}
df = pd.DataFrame(df_dict)
df
# Out:
#    도시      인구수
# 0  서울  9741381
# 1  부산  3416918
# 2  인천  2925967
# 3  대구  2453041
# 4  대전  1525849
# 5  광주  1496172
# 6  수원  1193894
# 7  울산  1147037
# 8  고양  1068641
# 9  용인  1061440

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pwd
# Out:
# '/content'

# %%
df.to_csv('/content/drive/my drive/pandas/data/df02.csv', index=True, header=True)

# %%
df.to_csv('/content/drive/my drive/pandas/data/df02.csv', index=False, header=True)

# %%
pd.read_csv('~/Desktop/df02.csv')
# Out:
#    도시      인구수
# 0  서울  9741381
# 1  부산  3416918
# 2  인천  2925967
# 3  대구  2453041
# 4  대전  1525849
# 5  광주  1496172
# 6  수원  1193894
# 7  울산  1147037
# 8  고양  1068641
# 9  용인  1061440
